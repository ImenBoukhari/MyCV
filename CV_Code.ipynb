# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# **************************** Text Variables

#      left fragment
# Introduction
Header = '# This resume was generated entirely in Python.'
Name = 'Imen BOUKHARI'
Title = ' 2nd year Software engineering student'
SubTitle='Tunisian Higher Institute Of Computer Science Ariana'
#section :Contact
#Country + Phone Number + Email + linkedin profile + Git
Contact = 'Tunisia, Tunis\n+216 94113858\nimen.boukhari@etudiant-isi.utm.tn\nin: imen-boukhari-991905172\ngithub.com/ImenBoukhari/MyCv'
#section :Skills
SkillsHeader = 'SKILLS'
SkillsDesc='Python, Pandas,  NumPy\nScikit-learn, Matplotlib, Tkinter\nSQL, Pl/SQL, Matlab\nR, PHP, Django\nJAVA, C++, C\nKotlin, HTML5, CSS3\nJS, Bootstarp5, Spring Boot\nAngular, Node.js, Camunda\nSTM32'
#section :Softwares
SoftwareHeader = 'Softwares & Platforms'
SoftwareDesc='Anaconda, Atom,  RStudio\nVSCode, Scilab, Matlab\nNetbeans , Intellij, Android Studio\nGit, UML Diagrammer, Latex\n'
#section :EXTRA-CURRICULAR ACTIVITIES
ActivitiesHeader="EXTRA-CURRICULAR ACTIVITIES"
ActivitiesTitle="Hackathon 48H 'Hack4Covid-19'"
Activitiesrank="Finalist, Organized by EY & Vneuron"
Activitiessubject="Realization of a platform that brings\ntogether the confined with the nutritionist\nthe coach-athlete, and the expert in human\ndevelopment to assist them in this period\nof stress in an atmosphere of games \nand competitions"
#section :INTERESTS
InterestsHeader="INTERESTS"
Interestsubject="Interior Architecture & Design\nHuman Psychology\nAstronomie\nPainting\nSinging"

#      Right fragment
#section : ACADEMIC QUALIFICATIONS
qualificationsHeader="ACADEMIC QUALIFICATIONS"
#last Diploma
lastDiplomaTitle="Bachelor of Computer Science"
lastDiplomaInst="Higher Institute Of Computer Science Ariana"
lastDiplomaPeriode="                   2018-2020      with high honours B+"

#first Diploma
firstDiplomaTitle="High school diploma of Computer Science"
firstDiplomaInst="Hannibal high school Ariana"
firstDiplomaPeriode="                   2014-2017      with high honours A-"

#section :PROFESSIONAL EXPERIENCE
expHeader='PROFESSIONAL EXPERIENCE'
#End-of-Studies Project
lastexpTitle='End-of-Studies Project '
lastexpLocation="Vneuron Charguia 2, Tunisa"
lastexpPeriode="                   02/2020 - 06/2020      with highest honour"
lastexpSubject="Design, implementation, and execution of a simulation system for banking stress test\nscenarios (including market, counterparty, and liquidity risks) based on banking risk \nmanagement methods (VaR, Monte Carlo) and Supervised Machine Learning\ntechniques (linear regression).  Python,Scikit-learn,NumPy"
FirstexpSubject="Realization of a web application for stock management and invoicing. Native programming HTML5, CSS3,JS, PHP4)."

#section : CERTIFICATES
certifHeader="CERTIFICATES"

certifTitle1="Introduction to Data Science in Python"
certifOrganization1="University of Michigan, Corsera        02/2022"
certifSubject1="-Describe common Python functionality and features used for data science\n-Query DataFrame structures for cleaning and processing\n-Explain distributions, sampling, and t-tests\n-Understand techniques such as lambdas and manipulating csv files"

certifTitle2="Data visualisation"
certifOrganization2="HarvardX Energy Dispersive X-Ray Analysis (EDX)        01/2021"
certifSubject2="-Principles of data visualization and study of distributions using R and ggplot2\nfor data analysis\n-Summarize data using dplyr."

certifTitle3="Introduction to Data Science"
certifOrganization3="IBM Energy Dispersive X-Ray Analysis (EDX)        01/2021"
certifSubject3="Definition of data science and what data scientists do\n- Tools and algorithms used on a daily basis within the field\n-Skills needed to be a successful data scientist\n-The role of data science within a business\n-How to form a strong data science team"

certifTitle4="Machine Learning for Data Science and Analytics"
certifOrganization4="ColumbiaX Energy Dispersive X-Ray Analysis (EDX)        01/2021"
certifSubject4="-What machine learning is and how it is related to statistics and data analysis\n-How machine learning uses computer algorithms to search for patterns in data\n-How to prepare data for analytics solutions\n-Basic and frequently used algorithmic techniques including sorting, searching\n greedy algorithms an dynamic programming"

certifTitle5="Learn Java"
certifOrganization5="Udemy        11/2019"


certifTitle6="Fundamentals of digital marketing"
certifOrganization6="Google Digital Workshop        09/2019"

# *****************************    Design
    #  Template configuration font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))
    # Template configuration colors
Fcolor='#69B0C7'
h1color="#65909C"
Periodescolor="#5C5D5D"
Left_fragment_color="#ffffff"
    # Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color=Fcolor,alpha=0.0, linewidth=100)
ax.axhline(y=1, color=Fcolor, linewidth=30)
plt.axvline(x=.0, color=Fcolor, linewidth=300)
# Contact zone
plt.axhline(y=.85, xmin=0, xmax=1, color='#ffffff', linewidth=2)
plt.axhline(y=.975, xmin=0, xmax=1, color='#ffffff', linewidth=3)
# *****************************   Add text variables to the plot
# Positions configurations
frag1=0.01
frag2=0.30
section1=.90
section2=.80
# top Left fragment
plt.annotate(Contact, (frag1,section1-.02), weight='regular', fontsize=10, color=Left_fragment_color)
#left fragment
#section : Skills
plt.annotate(SkillsHeader, (frag1,section2), weight='bold', fontsize=11.3, color='#ffffff')
plt.annotate(SkillsDesc, (frag1,section2-.2), weight='regular', fontsize=10, color='#ffffff')
#section :Software
section2=.56
plt.annotate(SoftwareHeader, (frag1,section2), weight='bold', fontsize=11.3, color='#ffffff')
plt.annotate(SoftwareDesc, (frag1,section2-.13), weight='regular', fontsize=10, color='#ffffff')
#section :EXTRA-CURRICULAR ACTIVITIES
section2=.40
plt.annotate(ActivitiesHeader, (frag1-.01,section2), weight='bold', fontsize=8.9, color='#ffffff')
plt.annotate(ActivitiesTitle, (frag1,section2-.06), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(Activitiesrank, (frag1,section2-.08), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Activitiessubject, (frag1,section2-.18), weight='regular', fontsize=8.5, color='#ffffff')
#section :INTERESTS
section2=.28
plt.annotate(InterestsHeader, (frag1,section2-.10), weight='bold', fontsize=11.3, color='#ffffff')
plt.annotate(Interestsubject, (frag1,section2-.21), weight='regular', fontsize=10, color='#ffffff')

#top right fragment
plt.annotate(Header, (frag2-0.05,section1+.085), weight='bold', fontsize=8.5, alpha=.75)
plt.annotate(Name, (frag2+.02,section1+.04), weight='bold', fontsize=18)
plt.annotate(Title, (frag2+.05,section1+.01), weight='regular', fontsize=14)
plt.annotate(SubTitle, (frag2+.05,section1-.02), weight='regular', fontsize=14)
# Right fragment
#section :ACADEMIC QUALIFICATIONS
section2=0.80
plt.annotate(qualificationsHeader, (frag2+.03,section2+.05), weight='bold', fontsize=10, color=h1color)
plt.annotate(lastDiplomaTitle, (frag2+.03,section2+.02), weight='bold', fontsize=10)
plt.annotate(lastDiplomaInst, (frag2+.03,section2), weight='regular', fontsize=9)
plt.annotate(lastDiplomaPeriode, (frag2+.03,section2-.02), weight='regular', fontsize=9,color=Periodescolor)

plt.annotate(firstDiplomaTitle, (frag2+.03,section2-.04), weight='bold', fontsize=10)
plt.annotate(firstDiplomaInst, (frag2+.03,section2-.06), weight='regular', fontsize=9)
plt.annotate(firstDiplomaPeriode, (frag2+.03,section2-.08), weight='regular', fontsize=9,color=Periodescolor)
#section :PROFESSIONAL EXPERIENCE
section3=0.65
plt.annotate(expHeader, (frag2+.03,section3+.05), weight='bold', fontsize=10, color=h1color)
plt.annotate(lastexpTitle, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(lastexpLocation, (frag2+.03,section3), weight='regular', fontsize=9)
plt.annotate(lastexpPeriode, (frag2+.03,section3-0.02), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(lastexpSubject, (frag2+.03,section3-.08), weight='regular', fontsize=9)
#section :CERTIFICATES
section3=0.50
plt.annotate(certifHeader, (frag2+.03,section3+.05), weight='bold', fontsize=10, color=h1color)
plt.annotate(certifTitle1, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(certifOrganization1, (frag2+.03,section3), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(certifSubject1, (frag2+.03,section3-0.06), weight='regular', fontsize=9)
section3=0.45
plt.annotate(certifTitle2, (frag2+.03,section3-.03), weight='bold', fontsize=10)
plt.annotate(certifOrganization2, (frag2+.03,section3-.05), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(certifSubject2, (frag2+.03,section3-0.1), weight='regular', fontsize=9)
section3=0.31
plt.annotate(certifTitle3, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(certifOrganization3, (frag2+.03,section3), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(certifSubject3, (frag2+.03,section3-0.08), weight='regular', fontsize=9)
section3=0.19
plt.annotate(certifTitle4, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(certifOrganization4, (frag2+.03,section3), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(certifSubject4, (frag2+.03,section3-0.08), weight='regular', fontsize=9)
section3=0.07
plt.annotate(certifTitle5, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(certifOrganization5, (frag2+.03,section3), weight='regular', fontsize=9,color=Periodescolor)
plt.annotate(certifSubject5, (frag2+.03,section3-.02), weight='regular', fontsize=9)
section3=0.01
plt.annotate(certifTitle6, (frag2+.03,section3+.02), weight='bold', fontsize=10)
plt.annotate(certifOrganization6, (frag2+.03,section3), weight='regular', fontsize=9,color=Periodescolor)

plt.axis('off')
plt.savefig('CvImenBoukhari_SummerInternship_DataScience.pdf', dpi=300, bbox_inches='tight')
